# %%
import pandas as pd
import numpy as np

# %%
#importing text documents
events = pd.read_csv("Event_Codes.txt", sep = '\t')
lineups = pd.read_csv("Game_Lineup.txt", sep = '\t')

#sorting play by play as suggested in pdf
playbyplay = pd.read_csv("Play_by_Play.txt", sep = '\t').sort_values(['Game_id',
                                                                           'Period', 
                                                                           'PC_Time',
                                                                           'WC_Time',
                                                                           'Event_Num'],
                                                                          ascending = [0, 1, 0, 1, 1])

# %%
events.head()
# Out:
#    Event_Msg_Type  Action_Type                Event_Msg_Type_Description  \
# 0               1            0  Made Shot
# 1               1            1  Made Shot
# 2               1            2  Made Shot
# 3               1            3  Made Shot
# 4               1            4  Made Shot
#
#   Action_Type_Description
# 0                 No Shot
# 1               Jump Shot
# 2       Running Jump Shot
# 3               Hook Shot
# 4                Tip Shot

# %%
playbyplay.head()
# Out:
#                                 Game_id  Event_Num  Event_Msg_Type  Period  \
# 37396  ff42c1cba89fd3f3a7a6711a11d5576d          2              12       1
# 37397  ff42c1cba89fd3f3a7a6711a11d5576d          4              10       1
# 37398  ff42c1cba89fd3f3a7a6711a11d5576d          7               2       1
# 37399  ff42c1cba89fd3f3a7a6711a11d5576d          8               4       1
# 37400  ff42c1cba89fd3f3a7a6711a11d5576d          9               1       1
#
#        WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 37396   510450     7200            0        0        0        0
# 37397   510460     7200            0        0        0        0
# 37398   510580     7070           79        2        0        0
# 37399   510610     7030            0        0        0        0
# 37400   510660     6980            1        3        1        0
#
#                                 Team_id                           Person1  \
# ...

# %%
lineups.head()
# Out:
#                             Game_id  Period                         Person_id  \
# 0  006728e4c10e957011e1f24878e6054a       0  ae53f8ba6761b64a174051da817785bc
# 1  006728e4c10e957011e1f24878e6054a       0  44230324724c84f122ac62a5f0918314
# 2  006728e4c10e957011e1f24878e6054a       0  8d2127290c94bd41b82a2938734bc750
# 3  006728e4c10e957011e1f24878e6054a       0  48ec4e6c52f418d5ca4ef510ba473ea0
# 4  006728e4c10e957011e1f24878e6054a       0  e816ff284dc3f965b8f3d605a3b91bae
#
#                             Team_id status
# 0  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 1  45ba8fc87f55b1191c50c400dc7ed11c      A
# 2  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A
# 3  45ba8fc87f55b1191c50c400dc7ed11c      A
# 4  01be0ad4af7aeb1f6d2cc2b6b6d6d811      A

# %%
# these should all be 10 which it looks like they are
lineups[(lineups.status=='A') & (lineups.Period!=0)].groupby(by=['Game_id','Period']).count()
# Out:
#                                          Person_id  Team_id  status
# Game_id                          Period
# 006728e4c10e957011e1f24878e6054a 1              10       10      10
#                                  2              10       10      10
#                                  3              10       10      10
#                                  4              10       10      10
# 03ac65b9a32fde1e201bfb427f6e41e4 1              10       10      10
#                                  2              10       10      10
#                                  3              10       10      10
#                                  4              10       10      10
# 096e231adad0be6ab1cc89cce56847f8 1              10       10      10
#                                  2              10       10      10
#                                  3              10       10      10
#                                  4              10       10      10
# ...

# %%
df = playbyplay.merge(lineups,
                     left_on='Game_id',
                     right_on='Game_id')

# %%
len(df)
# Out:
# 2672640

# %%
len(playbyplay)
# Out:
# 37889

# %%
len(df) / len(playbyplay) # seems ok
# Out:
# 70.53867877220301
